# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lat = np.random.uniform(low = -90.000,high = 90.000,size = 2000)
lngs = np.random.uniform(low = -180.000,high = 180.000,size = 2000)
lat_lngs = zip(lat , lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c856b7532671c47aebbc0a402db9377b"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_Description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_Description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pisco
# Processing Record 2 of Set 1 | tuatapere
# Processing Record 3 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 1 | belyy yar
# Processing Record 5 of Set 1 | grindavik
# Processing Record 6 of Set 1 | portland
# Processing Record 7 of Set 1 | aklavik
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | qaqortoq
# Processing Record 11 of Set 1 | nome
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | lormi
# Processing Record 14 of Set 1 | tartus
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | beidao
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | peleduy
# Processing Record 22 of Set 1 | nuuk
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | warrington
# Processing Record 25 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | comodoro rivadavia
# Processing Record 28 of Set 1 | meulaboh
# Processing Record 29 of Set 1 | huazolotitlan
# City not found. Skipping...
# Processing Record 30 of Set 1 | rafai
# Processing Record 31 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | brownsville
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | shimoda
# Processing Record 37 of Set 1 | kirakira
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | provideniya
# Processing Record 43 of Set 1 | massaguet
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | senador jose porfirio
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | messina
# Processing Record 49 of Set 1 | pevek
# Processing Record 50 of Set 1 | bermeo
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | inuvik
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | rexburg
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | latung
# Processing Record 10 of Set 2 | kutum
# Processing Record 11 of Set 2 | codrington
# Processing Record 12 of Set 2 | mukhanovo
# City not found. Skipping...
# Processing Record 13 of Set 2 | beringovskiy
# Processing Record 14 of Set 2 | alice springs
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | orocue
# Processing Record 17 of Set 2 | llandrindod wells
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | khash
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | esperance
# Processing Record 22 of Set 2 | bathsheba
# Processing Record 23 of Set 2 | poum
# Processing Record 24 of Set 2 | ayorou
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | shingu
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | bilma
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | esmeraldas
# Processing Record 32 of Set 2 | cervo
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | kaspiysk
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | busselton
# Processing Record 37 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | olafsvik
# Processing Record 40 of Set 2 | huilong
# Processing Record 41 of Set 2 | mao
# Processing Record 42 of Set 2 | lorengau
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | ciras
# City not found. Skipping...
# Processing Record 46 of Set 2 | punta arenas
# Processing Record 47 of Set 2 | nenjiang
# Processing Record 48 of Set 2 | kununurra
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | mandalgovi
# Processing Record 1 of Set 3 | lima
# Processing Record 2 of Set 3 | trinidad
# Processing Record 3 of Set 3 | manzhouli
# Processing Record 4 of Set 3 | vestmannaeyjar
# Processing Record 5 of Set 3 | guilin
# Processing Record 6 of Set 3 | marondera
# Processing Record 7 of Set 3 | viedma
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | ust-kalmanka
# Processing Record 10 of Set 3 | port alfred
# Processing Record 11 of Set 3 | liwale
# Processing Record 12 of Set 3 | gizo
# Processing Record 13 of Set 3 | kavaratti
# Processing Record 14 of Set 3 | constitucion
# Processing Record 15 of Set 3 | roma
# Processing Record 16 of Set 3 | santa catarina de tepehuanes
# Processing Record 17 of Set 3 | atoyac
# Processing Record 18 of Set 3 | mabaruma
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | okhotsk
# Processing Record 22 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 3 | mogadishu
# Processing Record 25 of Set 3 | ghanzi
# Processing Record 26 of Set 3 | egvekinot
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | atherton
# Processing Record 29 of Set 3 | moroeni
# Processing Record 30 of Set 3 | laguna
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | mount isa
# Processing Record 33 of Set 3 | cockburn town
# Processing Record 34 of Set 3 | rawson
# Processing Record 35 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 3 | san benito
# Processing Record 37 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | nikel
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | bundaberg
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | westport
# Processing Record 44 of Set 3 | haines junction
# Processing Record 45 of Set 3 | minab
# Processing Record 46 of Set 3 | voiron
# Processing Record 47 of Set 3 | cap malheureux
# Processing Record 48 of Set 3 | alcala la real
# Processing Record 49 of Set 3 | hobyo
# Processing Record 50 of Set 3 | buluang
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | kapaa
# Processing Record 3 of Set 4 | kodiak
# Processing Record 4 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 4 | hokitika
# Processing Record 6 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 4 | saint-philippe
# Processing Record 8 of Set 4 | pirgos
# Processing Record 9 of Set 4 | mount gambier
# Processing Record 10 of Set 4 | morant bay
# Processing Record 11 of Set 4 | puerto ayora
# Processing Record 12 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 4 | santa barbara
# Processing Record 14 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 4 | ouegoa
# Processing Record 16 of Set 4 | los llanos de aridane
# Processing Record 17 of Set 4 | barrow
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 4 | caravelas
# Processing Record 21 of Set 4 | maryborough
# Processing Record 22 of Set 4 | kjollefjord
# Processing Record 23 of Set 4 | lasa
# Processing Record 24 of Set 4 | orange cove
# Processing Record 25 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | adrar
# Processing Record 28 of Set 4 | anadyr
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | loreto
# Processing Record 31 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 4 | vostok
# Processing Record 33 of Set 4 | ostrovnoy
# Processing Record 34 of Set 4 | zatoka
# Processing Record 35 of Set 4 | buchanan
# Processing Record 36 of Set 4 | south venice
# Processing Record 37 of Set 4 | ampanihy
# Processing Record 38 of Set 4 | paratinga
# Processing Record 39 of Set 4 | havelock
# Processing Record 40 of Set 4 | norman wells
# Processing Record 41 of Set 4 | eydhafushi
# Processing Record 42 of Set 4 | bhatkal
# Processing Record 43 of Set 4 | avarua
# Processing Record 44 of Set 4 | boyolangu
# Processing Record 45 of Set 4 | ongandjera
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | mae hong son
# Processing Record 48 of Set 4 | gloversville
# Processing Record 49 of Set 4 | ballina
# Processing Record 50 of Set 4 | arman
# Processing Record 1 of Set 5 | isangel
# Processing Record 2 of Set 5 | atasu
# Processing Record 3 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 5 | port pirie
# Processing Record 5 of Set 5 | surt
# Processing Record 6 of Set 5 | agadir
# Processing Record 7 of Set 5 | vardo
# Processing Record 8 of Set 5 | chara
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | tikrit
# Processing Record 11 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | nacala
# Processing Record 13 of Set 5 | ribeira grande
# Processing Record 14 of Set 5 | puerto del rosario
# Processing Record 15 of Set 5 | champerico
# Processing Record 16 of Set 5 | praia da vitoria
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | poddorye
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | pitea
# Processing Record 23 of Set 5 | juegang
# Processing Record 24 of Set 5 | winnemucca
# Processing Record 25 of Set 5 | san cristobal
# Processing Record 26 of Set 5 | mendoza
# Processing Record 27 of Set 5 | mehamn
# Processing Record 28 of Set 5 | sao filipe
# Processing Record 29 of Set 5 | flin flon
# Processing Record 30 of Set 5 | bria
# Processing Record 31 of Set 5 | la asuncion
# Processing Record 32 of Set 5 | veraval
# Processing Record 33 of Set 5 | bonavista
# Processing Record 34 of Set 5 | san jeronimo
# Processing Record 35 of Set 5 | axim
# Processing Record 36 of Set 5 | nanortalik
# Processing Record 37 of Set 5 | goalpara
# Processing Record 38 of Set 5 | sola
# Processing Record 39 of Set 5 | muzhi
# Processing Record 40 of Set 5 | dauphin
# Processing Record 41 of Set 5 | lavrentiya
# Processing Record 42 of Set 5 | port lincoln
# Processing Record 43 of Set 5 | northam
# Processing Record 44 of Set 5 | acin
# City not found. Skipping...
# Processing Record 45 of Set 5 | sakakah
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | kinanah
# City not found. Skipping...
# Processing Record 48 of Set 5 | atar
# Processing Record 49 of Set 5 | hede
# Processing Record 50 of Set 5 | airai
# Processing Record 1 of Set 6 | gorontalo
# Processing Record 2 of Set 6 | komsomolskiy
# Processing Record 3 of Set 6 | marshall
# Processing Record 4 of Set 6 | aripuana
# Processing Record 5 of Set 6 | avera
# Processing Record 6 of Set 6 | pingliang
# Processing Record 7 of Set 6 | blagoyevo
# Processing Record 8 of Set 6 | baker city
# Processing Record 9 of Set 6 | verkhnetulomskiy
# Processing Record 10 of Set 6 | berlevag
# Processing Record 11 of Set 6 | klaksvik
# Processing Record 12 of Set 6 | longyearbyen
# Processing Record 13 of Set 6 | pangody
# Processing Record 14 of Set 6 | aksu
# Processing Record 15 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 6 | hambantota
# Processing Record 17 of Set 6 | gonbad-e qabus
# Processing Record 18 of Set 6 | sunland park
# Processing Record 19 of Set 6 | lipin bor
# Processing Record 20 of Set 6 | ingham
# Processing Record 21 of Set 6 | itarema
# Processing Record 22 of Set 6 | sirjan
# Processing Record 23 of Set 6 | sitka
# Processing Record 24 of Set 6 | basco
# Processing Record 25 of Set 6 | gao
# Processing Record 26 of Set 6 | enid
# Processing Record 27 of Set 6 | belmonte
# Processing Record 28 of Set 6 | port hedland
# Processing Record 29 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | ilulissat
# Processing Record 31 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 32 of Set 6 | amahai
# Processing Record 33 of Set 6 | iqaluit
# Processing Record 34 of Set 6 | lakselv
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | henties bay
# Processing Record 37 of Set 6 | holme
# Processing Record 38 of Set 6 | baherden
# Processing Record 39 of Set 6 | taga
# Processing Record 40 of Set 6 | biharamulo
# Processing Record 41 of Set 6 | kaitangata
# Processing Record 42 of Set 6 | fomboni
# Processing Record 43 of Set 6 | tasiilaq
# Processing Record 44 of Set 6 | makakilo city
# Processing Record 45 of Set 6 | lokosovo
# Processing Record 46 of Set 6 | sayat
# Processing Record 47 of Set 6 | sokolniki
# Processing Record 48 of Set 6 | saint-francois
# Processing Record 49 of Set 6 | georgetown
# Processing Record 50 of Set 6 | karonga
# Processing Record 1 of Set 7 | souillac
# Processing Record 2 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 7 | abha
# Processing Record 4 of Set 7 | yenagoa
# Processing Record 5 of Set 7 | lagoa
# Processing Record 6 of Set 7 | newberry
# Processing Record 7 of Set 7 | yerbogachen
# Processing Record 8 of Set 7 | boddam
# Processing Record 9 of Set 7 | saint-joseph
# Processing Record 10 of Set 7 | auki
# Processing Record 11 of Set 7 | zabolotovka
# Processing Record 12 of Set 7 | kasongo-lunda
# Processing Record 13 of Set 7 | muros
# Processing Record 14 of Set 7 | abu samrah
# Processing Record 15 of Set 7 | rio grande
# Processing Record 16 of Set 7 | grand-lahou
# Processing Record 17 of Set 7 | oranjemund
# Processing Record 18 of Set 7 | karratha
# Processing Record 19 of Set 7 | fukue
# Processing Record 20 of Set 7 | kavieng
# Processing Record 21 of Set 7 | saldanha
# Processing Record 22 of Set 7 | oktyabrskiy
# Processing Record 23 of Set 7 | yarada
# Processing Record 24 of Set 7 | valuyki
# Processing Record 25 of Set 7 | fort-shevchenko
# Processing Record 26 of Set 7 | jalu
# Processing Record 27 of Set 7 | tula
# Processing Record 28 of Set 7 | miri
# Processing Record 29 of Set 7 | totness
# Processing Record 30 of Set 7 | luderitz
# Processing Record 31 of Set 7 | trelew
# Processing Record 32 of Set 7 | haradok
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 7 | salalah
# Processing Record 36 of Set 7 | sur
# Processing Record 37 of Set 7 | ahipara
# Processing Record 38 of Set 7 | dudinka
# Processing Record 39 of Set 7 | causapscal
# Processing Record 40 of Set 7 | bubaque
# Processing Record 41 of Set 7 | ushtobe
# Processing Record 42 of Set 7 | oriximina
# Processing Record 43 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 44 of Set 7 | leningradskiy
# Processing Record 45 of Set 7 | iskateley
# Processing Record 46 of Set 7 | burla
# Processing Record 47 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 7 | vila
# Processing Record 49 of Set 7 | mujiayingzi
# Processing Record 50 of Set 7 | xining
# Processing Record 1 of Set 8 | leninskoye
# Processing Record 2 of Set 8 | nouadhibou
# Processing Record 3 of Set 8 | kota belud
# Processing Record 4 of Set 8 | coria
# Processing Record 5 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 8 | lhokseumawe
# Processing Record 7 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 8 | jibuti
# Processing Record 9 of Set 8 | harper
# Processing Record 10 of Set 8 | kruisfontein
# Processing Record 11 of Set 8 | makasar
# Processing Record 12 of Set 8 | samarai
# Processing Record 13 of Set 8 | matsanga
# City not found. Skipping...
# Processing Record 14 of Set 8 | mahon
# Processing Record 15 of Set 8 | vila franca do campo
# Processing Record 16 of Set 8 | vao
# Processing Record 17 of Set 8 | pucallpa
# Processing Record 18 of Set 8 | evensk
# Processing Record 19 of Set 8 | kieta
# Processing Record 20 of Set 8 | canavieiras
# Processing Record 21 of Set 8 | chala
# Processing Record 22 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 8 | luanda
# Processing Record 24 of Set 8 | naco
# Processing Record 25 of Set 8 | da lat
# Processing Record 26 of Set 8 | fort nelson
# Processing Record 27 of Set 8 | fortuna
# Processing Record 28 of Set 8 | izumo
# Processing Record 29 of Set 8 | jonesboro
# Processing Record 30 of Set 8 | alamosa
# Processing Record 31 of Set 8 | clyde river
# Processing Record 32 of Set 8 | nestorion
# City not found. Skipping...
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 8 | manono
# Processing Record 37 of Set 8 | kenmare
# Processing Record 38 of Set 8 | carutapera
# Processing Record 39 of Set 8 | narsaq
# Processing Record 40 of Set 8 | san andres
# Processing Record 41 of Set 8 | dawson creek
# Processing Record 42 of Set 8 | seguela
# Processing Record 43 of Set 8 | colares
# Processing Record 44 of Set 8 | guelph
# Processing Record 45 of Set 8 | palau
# Processing Record 46 of Set 8 | odda
# Processing Record 47 of Set 8 | matara
# Processing Record 48 of Set 8 | yelizovo
# Processing Record 49 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 8 | flinders
# Processing Record 1 of Set 9 | bengkulu
# Processing Record 2 of Set 9 | yulara
# Processing Record 3 of Set 9 | banda aceh
# Processing Record 4 of Set 9 | antalaha
# Processing Record 5 of Set 9 | makung
# City not found. Skipping...
# Processing Record 6 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 9 | gobabis
# Processing Record 8 of Set 9 | marrakesh
# Processing Record 9 of Set 9 | oussouye
# Processing Record 10 of Set 9 | kisangani
# Processing Record 11 of Set 9 | baracoa
# Processing Record 12 of Set 9 | sovetskiy
# Processing Record 13 of Set 9 | bud
# Processing Record 14 of Set 9 | mizdah
# Processing Record 15 of Set 9 | cidreira
# Processing Record 16 of Set 9 | pryazha
# Processing Record 17 of Set 9 | ahuimanu
# Processing Record 18 of Set 9 | ukiah
# Processing Record 19 of Set 9 | ligayan
# Processing Record 20 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 9 | kattivakkam
# Processing Record 22 of Set 9 | shagonar
# Processing Record 23 of Set 9 | acton
# Processing Record 24 of Set 9 | chiredzi
# Processing Record 25 of Set 9 | kropotkin
# Processing Record 26 of Set 9 | upernavik
# Processing Record 27 of Set 9 | lompoc
# Processing Record 28 of Set 9 | srednekolymsk
# Processing Record 29 of Set 9 | yumen
# Processing Record 30 of Set 9 | campana
# Processing Record 31 of Set 9 | palana
# Processing Record 32 of Set 9 | chapais
# Processing Record 33 of Set 9 | baykit
# Processing Record 34 of Set 9 | pouembout
# Processing Record 35 of Set 9 | chabahar
# Processing Record 36 of Set 9 | kiama
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | bam
# Processing Record 39 of Set 9 | makokou
# Processing Record 40 of Set 9 | maymanak
# City not found. Skipping...
# Processing Record 41 of Set 9 | hasaki
# Processing Record 42 of Set 9 | darasun
# Processing Record 43 of Set 9 | nyimba
# Processing Record 44 of Set 9 | sao gabriel da cachoeira
# Processing Record 45 of Set 9 | burgeo
# Processing Record 46 of Set 9 | asau
# Processing Record 47 of Set 9 | puerto baquerizo moreno
# Processing Record 48 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 9 | bandarbeyla
# Processing Record 50 of Set 9 | russell
# Processing Record 1 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 2 of Set 10 | la vista
# Processing Record 3 of Set 10 | letnica
# Processing Record 4 of Set 10 | tilichiki
# Processing Record 5 of Set 10 | yeniseysk
# Processing Record 6 of Set 10 | lagunas
# Processing Record 7 of Set 10 | novyy urgal
# Processing Record 8 of Set 10 | progreso
# Processing Record 9 of Set 10 | faanui
# Processing Record 10 of Set 10 | puerto leguizamo
# Processing Record 11 of Set 10 | waipawa
# Processing Record 12 of Set 10 | jieshi
# Processing Record 13 of Set 10 | santa rosa
# Processing Record 14 of Set 10 | goderich
# Processing Record 15 of Set 10 | north bend
# Processing Record 16 of Set 10 | killybegs
# Processing Record 17 of Set 10 | bilaspur
# Processing Record 18 of Set 10 | acarau
# Processing Record 19 of Set 10 | la ciotat
# Processing Record 20 of Set 10 | port macquarie
# Processing Record 21 of Set 10 | hami
# Processing Record 22 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 10 | tabuk
# Processing Record 24 of Set 10 | bac lieu
# Processing Record 25 of Set 10 | mantes-la-ville
# Processing Record 26 of Set 10 | sayyan
# Processing Record 27 of Set 10 | coihaique
# Processing Record 28 of Set 10 | bagdarin
# Processing Record 29 of Set 10 | baruun-urt
# Processing Record 30 of Set 10 | wenling
# Processing Record 31 of Set 10 | teya
# Processing Record 32 of Set 10 | gweta
# Processing Record 33 of Set 10 | jiaozuo
# Processing Record 34 of Set 10 | dukat
# Processing Record 35 of Set 10 | karasjok
# Processing Record 36 of Set 10 | pangnirtung
# Processing Record 37 of Set 10 | bontang
# Processing Record 38 of Set 10 | orlik
# Processing Record 39 of Set 10 | mari-turek
# Processing Record 40 of Set 10 | ayr
# Processing Record 41 of Set 10 | ternate
# Processing Record 42 of Set 10 | lata
# Processing Record 43 of Set 10 | half moon bay
# Processing Record 44 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 46 of Set 10 | potiskum
# Processing Record 47 of Set 10 | pavlivka
# Processing Record 48 of Set 10 | minot
# Processing Record 49 of Set 10 | myaundzha
# Processing Record 50 of Set 10 | altay
# Processing Record 1 of Set 11 | plainview
# Processing Record 2 of Set 11 | tocopilla
# Processing Record 3 of Set 11 | san ignacio
# Processing Record 4 of Set 11 | urumqi
# Processing Record 5 of Set 11 | jambi
# Processing Record 6 of Set 11 | mogocha
# Processing Record 7 of Set 11 | soverato
# Processing Record 8 of Set 11 | kalabo
# Processing Record 9 of Set 11 | venado tuerto
# Processing Record 10 of Set 11 | kagoro
# Processing Record 11 of Set 11 | benguela
# Processing Record 12 of Set 11 | cauquenes
# Processing Record 13 of Set 11 | husavik
# Processing Record 14 of Set 11 | cabo san lucas
# Processing Record 15 of Set 11 | rocky mountain house
# Processing Record 16 of Set 11 | ancud
# Processing Record 17 of Set 11 | zemio
# Processing Record 18 of Set 11 | dmytrivka
# Processing Record 19 of Set 11 | minggang
# Processing Record 20 of Set 11 | manyana
# Processing Record 21 of Set 11 | luba
# Processing Record 22 of Set 11 | kibondo
# Processing Record 23 of Set 11 | dubovskoye
# Processing Record 24 of Set 11 | presidencia roque saenz pena
# Processing Record 25 of Set 11 | along
# Processing Record 26 of Set 11 | aykhal
# Processing Record 27 of Set 11 | okha
# Processing Record 28 of Set 11 | sao jose da coroa grande
# Processing Record 29 of Set 11 | kapit
# Processing Record 30 of Set 11 | palmer
# Processing Record 31 of Set 11 | tshane
# Processing Record 32 of Set 11 | quelimane
# Processing Record 33 of Set 11 | kaeo
# Processing Record 34 of Set 11 | jumla
# Processing Record 35 of Set 11 | tchollire
# Processing Record 36 of Set 11 | havre-saint-pierre
# Processing Record 37 of Set 11 | zhigansk
# Processing Record 38 of Set 11 | filadelfia
# Processing Record 39 of Set 11 | innisfail
# Processing Record 40 of Set 11 | hulan
# Processing Record 41 of Set 11 | galle
# Processing Record 42 of Set 11 | boone
# Processing Record 43 of Set 11 | nabire
# Processing Record 44 of Set 11 | naze
# Processing Record 45 of Set 11 | iwanai
# Processing Record 46 of Set 11 | dzaoudzi
# Processing Record 47 of Set 11 | tura
# Processing Record 48 of Set 11 | sternberk
# Processing Record 49 of Set 11 | erenhot
# Processing Record 50 of Set 11 | yaan
# Processing Record 1 of Set 12 | nemuro
# Processing Record 2 of Set 12 | luang prabang
# Processing Record 3 of Set 12 | mount darwin
# Processing Record 4 of Set 12 | ca mau
# Processing Record 5 of Set 12 | artyom
# Processing Record 6 of Set 12 | soe
# Processing Record 7 of Set 12 | aspe
# Processing Record 8 of Set 12 | fairbanks
# Processing Record 9 of Set 12 | raudeberg
# Processing Record 10 of Set 12 | hanyang
# Processing Record 11 of Set 12 | swellendam
# Processing Record 12 of Set 12 | balsas
# Processing Record 13 of Set 12 | sampit
# Processing Record 14 of Set 12 | mackenzie
# Processing Record 15 of Set 12 | palmas
# Processing Record 16 of Set 12 | kalmunai
# Processing Record 17 of Set 12 | alofi
# Processing Record 18 of Set 12 | tomatlan
# Processing Record 19 of Set 12 | burica
# City not found. Skipping...
# Processing Record 20 of Set 12 | vila do maio
# Processing Record 21 of Set 12 | radishchevo
# Processing Record 22 of Set 12 | anju
# Processing Record 23 of Set 12 | sorland
# Processing Record 24 of Set 12 | magrath
# Processing Record 25 of Set 12 | mersing
# Processing Record 26 of Set 12 | igdir
# Processing Record 27 of Set 12 | zalari
# Processing Record 28 of Set 12 | nantucket
# Processing Record 29 of Set 12 | macapa
# Processing Record 30 of Set 12 | toora-khem
# Processing Record 31 of Set 12 | aberdeen
# Processing Record 32 of Set 12 | gallup
# Processing Record 33 of Set 12 | bougouni
# Processing Record 34 of Set 12 | qabis
# City not found. Skipping...
# Processing Record 35 of Set 12 | geraldton
# Processing Record 36 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 12 | sept-iles
# Processing Record 38 of Set 12 | marquette
# Processing Record 39 of Set 12 | mangrol
# Processing Record 40 of Set 12 | luorong
# Processing Record 41 of Set 12 | ambanja
# Processing Record 42 of Set 12 | akcaabat
# Processing Record 43 of Set 12 | palu
# Processing Record 44 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 45 of Set 12 | puerto carreno
# Processing Record 46 of Set 12 | solnechnyy
# Processing Record 47 of Set 12 | petatlan
# Processing Record 48 of Set 12 | hailar
# Processing Record 49 of Set 12 | terra santa
# Processing Record 50 of Set 12 | teshie
# Processing Record 1 of Set 13 | baghdad
# Processing Record 2 of Set 13 | imeni babushkina
# Processing Record 3 of Set 13 | skibbereen
# Processing Record 4 of Set 13 | den helder
# Processing Record 5 of Set 13 | kloulklubed
# Processing Record 6 of Set 13 | lazarev
# Processing Record 7 of Set 13 | yar-sale
# Processing Record 8 of Set 13 | brae
# Processing Record 9 of Set 13 | castres
# Processing Record 10 of Set 13 | hoquiam
# Processing Record 11 of Set 13 | cabra
# Processing Record 12 of Set 13 | uyuni
# Processing Record 13 of Set 13 | akyab
# Processing Record 14 of Set 13 | porto novo
# Processing Record 15 of Set 13 | teguldet
# Processing Record 16 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 13 | puerto maldonado
# Processing Record 18 of Set 13 | baymak
# Processing Record 19 of Set 13 | himora
# City not found. Skipping...
# Processing Record 20 of Set 13 | mushie
# Processing Record 21 of Set 13 | varhaug
# Processing Record 22 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 13 | parfino
# Processing Record 24 of Set 13 | margate
# Processing Record 25 of Set 13 | humaita
# Processing Record 26 of Set 13 | saint-georges
# Processing Record 27 of Set 13 | totskoye
# Processing Record 28 of Set 13 | ganta
# Processing Record 29 of Set 13 | broome
# Processing Record 30 of Set 13 | quatre cocos
# Processing Record 31 of Set 13 | severo-yeniseyskiy
# Processing Record 32 of Set 13 | abaujszanto
# Processing Record 33 of Set 13 | guaruja
# Processing Record 34 of Set 13 | seymchan
# Processing Record 35 of Set 13 | itoman
# Processing Record 36 of Set 13 | wahiawa
# Processing Record 37 of Set 13 | saiha
# Processing Record 38 of Set 13 | sao pedro
# Processing Record 39 of Set 13 | quimper
# Processing Record 40 of Set 13 | gat
# Processing Record 41 of Set 13 | sapao
# City not found. Skipping...
# Processing Record 42 of Set 13 | erdaojiang
# Processing Record 43 of Set 13 | vila velha
# Processing Record 44 of Set 13 | north platte
# Processing Record 45 of Set 13 | saint-augustin
# Processing Record 46 of Set 13 | ejea de los caballeros
# Processing Record 47 of Set 13 | katobu
# Processing Record 48 of Set 13 | teacapan
# Processing Record 49 of Set 13 | dunedin
# Processing Record 50 of Set 13 | san juan evangelista
# Processing Record 1 of Set 14 | jijiga
# Processing Record 2 of Set 14 | istisu
# Processing Record 3 of Set 14 | tual
# Processing Record 4 of Set 14 | busia
# Processing Record 5 of Set 14 | kouango
# Processing Record 6 of Set 14 | wolfsburg
# Processing Record 7 of Set 14 | bilibino
# Processing Record 8 of Set 14 | houma
# Processing Record 9 of Set 14 | cartagena
# Processing Record 10 of Set 14 | flagstaff
# Processing Record 11 of Set 14 | itaituba
# Processing Record 12 of Set 14 | kingston
# Processing Record 13 of Set 14 | gamba
# Processing Record 14 of Set 14 | newport
# Processing Record 15 of Set 14 | puerto escondido
# Processing Record 16 of Set 14 | hofn
# Processing Record 17 of Set 14 | guangyuan
# Processing Record 18 of Set 14 | plavinas
# Processing Record 19 of Set 14 | broken hill
# Processing Record 20 of Set 14 | southbridge
# Processing Record 21 of Set 14 | shirgaon
# Processing Record 22 of Set 14 | biak
# Processing Record 23 of Set 14 | nortelandia
# Processing Record 24 of Set 14 | preobrazheniye
# Processing Record 25 of Set 14 | tezu
# Processing Record 26 of Set 14 | constantine
# Processing Record 27 of Set 14 | minnedosa
# Processing Record 28 of Set 14 | chioggia
# Processing Record 29 of Set 14 | hirara
# Processing Record 30 of Set 14 | rorvik
# Processing Record 31 of Set 14 | kiunga
# Processing Record 32 of Set 14 | skjervoy
# Processing Record 33 of Set 14 | shahr-e kord
# Processing Record 34 of Set 14 | petrovskoye
# Processing Record 35 of Set 14 | honningsvag
# Processing Record 36 of Set 14 | coos bay
# Processing Record 37 of Set 14 | brodokalmak
# Processing Record 38 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 14 | quang ngai
# Processing Record 40 of Set 14 | ostashkov
# Processing Record 41 of Set 14 | gboko
# Processing Record 42 of Set 14 | sistranda
# Processing Record 43 of Set 14 | thabazimbi
# Processing Record 44 of Set 14 | sweetwater
# Processing Record 45 of Set 14 | coahuayana
# Processing Record 46 of Set 14 | port-gentil
# Processing Record 47 of Set 14 | maykor
# Processing Record 48 of Set 14 | ambon
# Processing Record 49 of Set 14 | santiago de cao
# Processing Record 50 of Set 14 | mikuni
# Processing Record 1 of Set 15 | durres
# Processing Record 2 of Set 15 | esil
# Processing Record 3 of Set 15 | kismayo
# Processing Record 4 of Set 15 | belaya gora
# Processing Record 5 of Set 15 | lang son
# Processing Record 6 of Set 15 | mouzakion
# City not found. Skipping...
# Processing Record 7 of Set 15 | pacific grove
# Processing Record 8 of Set 15 | monitos
# Processing Record 9 of Set 15 | coquimbo
# Processing Record 10 of Set 15 | havre
# Processing Record 11 of Set 15 | strzelce krajenskie
# Processing Record 12 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 13 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 15 | tahoua
# Processing Record 15 of Set 15 | boa vista
# Processing Record 16 of Set 15 | phayuha khiri
# Processing Record 17 of Set 15 | treinta y tres
# Processing Record 18 of Set 15 | trairi
# Processing Record 19 of Set 15 | port hardy
# Processing Record 20 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 15 | pithora
# Processing Record 22 of Set 15 | kerema
# Processing Record 23 of Set 15 | shieli
# Processing Record 24 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 15 | erdenet
# Processing Record 26 of Set 15 | sterling
# Processing Record 27 of Set 15 | kupang
# Processing Record 28 of Set 15 | hamilton
# Processing Record 29 of Set 15 | nybro
# Processing Record 30 of Set 15 | alakurtti
# Processing Record 31 of Set 15 | panaba
# Processing Record 32 of Set 15 | korla
# Processing Record 33 of Set 15 | namtsy
# Processing Record 34 of Set 15 | gornopravdinsk
# Processing Record 35 of Set 15 | sabancuy
# Processing Record 36 of Set 15 | bayanday
# Processing Record 37 of Set 15 | ascension
# Processing Record 38 of Set 15 | kota bahru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Pisco -13.7000  -76.2167     73.40        78           0       21.85
# 1    Tuatapere -46.1333  167.6833     57.00        74          30        8.99
# 2    Belyy Yar  53.6039   91.3903     19.40        58           0       11.18
# 3    Grindavik  63.8424  -22.4338     19.40        73           0        4.61
# 4     Portland  45.5234 -122.6762     46.99        87          90        6.91
# 5      Aklavik  68.2191 -135.0107     -2.20        84          75        4.61
# 6       Atuona  -9.8000 -139.0333     77.79        80         100       17.18
# 7  Yellowknife  62.4560 -114.3525      3.20        85          90        4.61
# 8     Qaqortoq  60.7167  -46.0333     41.00        38          90       23.02
# 9         Nome  64.5011 -165.4064     14.00        73          20       14.97
#
#   Country      Current Description
# 0      PE                clear sky
# 1      NZ         scattered clouds
# 2      RU                clear sky
# 3      IS                clear sky
# 4      US  light intensity drizzle
# 5      CA            broken clouds
# 6      PF          overcast clouds
# 7      CA          overcast clouds
# 8      GL          overcast clouds
# 9      US               few clouds

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

city_data_df =city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Pisco      PE -13.7000  -76.2167     73.40        78           0
# 1    Tuatapere      NZ -46.1333  167.6833     57.00        74          30
# 2    Belyy Yar      RU  53.6039   91.3903     19.40        58           0
# 3    Grindavik      IS  63.8424  -22.4338     19.40        73           0
# 4     Portland      US  45.5234 -122.6762     46.99        87          90
# 5      Aklavik      CA  68.2191 -135.0107     -2.20        84          75
# 6       Atuona      PF  -9.8000 -139.0333     77.79        80         100
# 7  Yellowknife      CA  62.4560 -114.3525      3.20        85          90
# 8     Qaqortoq      GL  60.7167  -46.0333     41.00        38          90
# 9         Nome      US  64.5011 -165.4064     14.00        73          20
#
#    Wind Speed      Current Description
# 0       21.85                clear sky
# 1        8.99         scattered clouds
# 2       11.18                clear sky
# 3        4.61                clear sky
# 4        6.91  light intensity drizzle
# 5        4.61            broken clouds
# 6       17.18          overcast clouds
# 7        4.61          overcast clouds
# 8       23.02          overcast clouds
# 9       14.97               few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
